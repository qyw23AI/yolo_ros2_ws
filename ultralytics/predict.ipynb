# %%
from ultralytics import YOLO
yolo = YOLO("./yolov8n.pt",task = "classify")
results = yolo(source="./ultralytics/assets/bus.jpg", save=True, conf = 0.7, iou = 0.9)
# Out:
# image 1/1 /home/qyw23ai/ultralytics/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 15.7ms
# Speed: 3.4ms preprocess, 15.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /home/qyw23ai/ultralytics/runs/detect/predict8

# %%
type(results)
# Out:
# list

# %%
result01 = results[0]
print(result01)
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
#绘制
import matplotlib.pyplot as plt
#这里的plot是yolo的RESULTS类中的plot方法，专门用于绘制结果
plt.imshow(result01.plot())
# 默认通道是 bgr,需要转成rgb

# %%
plt.imshow(result01.plot()[:,:,::-1])

# %%
#具体的信息都在result.boxes里面
print(result01.boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([5., 0., 0., 0., 0.], device='cuda:0')
# conf: tensor([0.8734, 0.8657, 0.8528, 0.8252, 0.7029], device='cuda:0')
# data: tensor([[2.2871e+01, 2.3128e+02, 8.0500e+02, 7.5684e+02, 8.7345e-01, 5.0000e+00],
#         [4.8550e+01, 3.9855e+02, 2.4535e+02, 9.0270e+02, 8.6569e-01, 0.0000e+00],
#         [6.6947e+02, 3.9219e+02, 8.0972e+02, 8.7704e+02, 8.5284e-01, 0.0000e+00],
#         [2.2152e+02, 4.0580e+02, 3.4497e+02, 8.5754e+02, 8.2523e-01, 0.0000e+00],
#         [4.8801e+01, 3.9772e+02, 2.2461e+02, 9.0405e+02, 7.0294e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 810)
# shape: torch.Size([5, 6])
# xywh: tensor([[413.9369, 494.0588, 782.1313, 525.5631],
#         [146.9480, 650.6275, 196.7951, 504.1504],
#         [739.5966, 634.6108, 140.2473, 484.8494],
#         [283.2440, 631.6676, 123.4533, 451.7380],
#         [136.7066, 650.8860, 175.8102, 506.3339]], device='cuda:0')
# ...
